# %%
import pandas as pd
import numpy as np


def intersect(a, b):
    return list(set(a) & set(b))


def get_features(train, test):
    trainval = list(train.columns.values)
    testval = list(test.columns.values)
    output = intersect(trainval, testval)
    output.remove('ID')
    return output


def prepare_dataset():
    train = pd.read_csv("train.csv")
    test = pd.read_csv("test.csv")
    features = train.columns.values
    
    norm_f = []
    for f in features:
        u = train[f].unique()
        if len(u) != 1:
            norm_f.append(f)


    remove = []
    for i in range(len(norm_f)):
        v1 = train[norm_f[i]].values
        for j in range(i+1, len(norm_f)):
            v2 = train[norm_f[j]].values
            if np.array_equal(v1, v2):
                remove.append(norm_f[j])
    
    for r in remove:
        norm_f.remove(r)

    train = train[norm_f]
    norm_f.remove('TARGET')
    test = test[norm_f]
    features = get_features(train, test)
    return train, test, features


def find_min_max_features(df, f):
    return df[f].min(), df[f].max()


def analayze_data(train, test):
    print('Length of train: ', len(train.index))
    train_zero = train[train['TARGET'] == 0]
    print('Length of train [TARGET = 0]: ', len(train_zero.index))
    train_one = train[train['TARGET'] == 1]
    print('Length of train [TARGET = 1]: ', len(train_one.index))
    # train_one.to_csv("debug.csv", index=False)
    one_range = dict()
    for f in train.columns:
        mn0, mx0 = find_min_max_features(train_zero, f)
        mn1, mx1 = find_min_max_features(train_one, f)
        mnt = 'N/A'
        mxt = 'N/A'
        if f in test.columns:
            mnt, mxt = find_min_max_features(test, f)
        one_range[f] = (mn1, mx1)
        if mn0 != mn1 or mn1 != mnt or mx0 != mx1 or mx1 != mxt:
            print("\nFeature {}".format(f))
            print("Range target=0  ({} - {})".format(mn0, mx0))
            print("Range target=1  ({} - {})".format(mn1, mx1))
            print("Range in test   ({} - {})".format(mnt, mxt))


train, test, features = prepare_dataset()
analayze_data(train, test)
# Out:
# ('Length of train: ', 76020)
# ('Length of train [TARGET = 0]: ', 73012)
# ('Length of train [TARGET = 1]: ', 3008)
#
# Feature ID
# Range target=0  (1 - 151838)
# Range target=1  (77 - 151811)
# Range in test   (2 - 151837)
#
# Feature var3
# Range target=0  (-999999 - 238)
# Range target=1  (-999999 - 142)
# Range in test   (-999999 - 238)
#
# Feature var15
# Range target=0  (5 - 105)
# Range target=1  (23 - 102)
# Range in test   (5 - 105)
#
# Feature imp_ent_var16_ult1
# Range target=0  (0.0 - 210000.0)
# Range target=1  (0.0 - 51003.0)
# Range in test   (0.0 - 240000.0)
#
# Feature imp_op_var39_comer_ult1
# Range target=0  (0.0 - 9968.04)
# Range target=1  (0.0 - 12888.03)
# Range in test   (0.0 - 21093.96)
#
# Feature imp_op_var39_comer_ult3
# Range target=0  (0.0 - 21024.81)
# Range target=1  (0.0 - 13183.23)
# Range in test   (0.0 - 47943.96)
#
# Feature imp_op_var40_comer_ult1
# Range target=0  (0.0 - 8237.82)
# Range target=1  (0.0 - 3639.87)
# Range in test   (0.0 - 21093.96)
#
# Feature imp_op_var40_comer_ult3
# Range target=0  (0.0 - 11073.57)
# Range target=1  (0.0 - 3639.87)
# Range in test   (0.0 - 47943.96)
#
# Feature imp_op_var40_efect_ult1
# Range target=0  (0.0 - 6600.0)
# Range target=1  (0.0 - 1800.0)
# Range in test   (0.0 - 6600.0)
#
# Feature imp_op_var40_efect_ult3
# Range target=0  (0.0 - 6600.0)
# Range target=1  (0.0 - 3000.0)
# Range in test   (0.0 - 6600.0)
#
# Feature imp_op_var40_ult1
# Range target=0  (0.0 - 8237.82)
# Range target=1  (0.0 - 2986.98)
# Range in test   (0.0 - 23799.96)
#
# Feature imp_op_var41_comer_ult1
# Range target=0  (0.0 - 9177.18)
# Range target=1  (0.0 - 12888.03)
# Range in test   (0.0 - 14784.9)
#
# Feature imp_op_var41_comer_ult3
# Range target=0  (0.0 - 16566.81)
# Range target=1  (0.0 - 13183.23)
# Range in test   (0.0 - 28927.89)
#
# Feature imp_op_var41_efect_ult1
# Range target=0  (0.0 - 45990.0)
# Range target=1  (0.0 - 13110.0)
# Range in test   (0.0 - 67500.0)
#
# Feature imp_op_var41_efect_ult3
# Range target=0  (0.0 - 131100.0)
# Range target=1  (0.0 - 13110.0)
# Range in test   (0.0 - 67950.0)
#
# Feature imp_op_var41_ult1
# Range target=0  (0.0 - 47598.09)
# Range target=1  (0.0 - 16220.55)
# Range in test   (0.0 - 72511.77)
#
# Feature imp_op_var39_efect_ult1
# Range target=0  (0.0 - 45990.0)
# Range target=1  (0.0 - 14010.0)
# Range in test   (0.0 - 67500.0)
#
# Feature imp_op_var39_efect_ult3
# Range target=0  (0.0 - 131100.0)
# Range target=1  (0.0 - 14010.0)
# Range in test   (0.0 - 67950.0)
#
# Feature imp_op_var39_ult1
# Range target=0  (0.0 - 47598.09)
# Range target=1  (0.0 - 16220.55)
# Range in test   (0.0 - 72511.77)
#
# Feature imp_sal_var16_ult1
# Range target=0  (0.0 - 105000.0)
# Range target=1  (0.0 - 10500.0)
# Range in test   (0.0 - 66000.0)
#
# Feature ind_var6_0
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature ind_var6
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature ind_var13_medio_0
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature ind_var18_0
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature ind_var20_0
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature ind_var20
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature ind_var33_0
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature ind_var33
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature ind_var34_0
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature num_var1
# Range target=0  (0 - 6)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature num_var4
# Range target=0  (0 - 7)
# Range target=1  (0 - 5)
# Range in test   (0 - 9)
#
# Feature num_var5_0
# Range target=0  (0 - 15)
# Range target=1  (0 - 6)
# Range in test   (0 - 12)
#
# Feature num_var5
# Range target=0  (0 - 15)
# Range target=1  (0 - 6)
# Range in test   (0 - 12)
#
# Feature num_var6_0
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_var6
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_var8_0
# Range target=0  (0 - 6)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature num_var12_0
# Range target=0  (0 - 15)
# Range target=1  (0 - 111)
# Range in test   (0 - 42)
#
# Feature num_var12
# Range target=0  (0 - 15)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature num_var13_0
# Range target=0  (0 - 18)
# Range target=1  (0 - 6)
# Range in test   (0 - 21)
#
# Feature num_var13_corto_0
# Range target=0  (0 - 6)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature num_var13_corto
# Range target=0  (0 - 6)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature num_var13_largo_0
# Range target=0  (0 - 18)
# Range target=1  (0 - 3)
# Range in test   (0 - 21)
#
# Feature num_var13_largo
# Range target=0  (0 - 18)
# Range target=1  (0 - 3)
# Range in test   (0 - 21)
#
# Feature num_var13_medio_0
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 6)
#
# Feature num_var13
# Range target=0  (0 - 18)
# Range target=1  (0 - 6)
# Range in test   (0 - 21)
#
# Feature num_var14_0
# Range target=0  (0 - 12)
# Range target=1  (0 - 111)
# Range in test   (0 - 42)
#
# Feature num_var14
# Range target=0  (0 - 12)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature num_var17_0
# Range target=0  (0 - 36)
# Range target=1  (0 - 21)
# Range in test   (0 - 66)
#
# Feature num_var17
# Range target=0  (0 - 27)
# Range target=1  (0 - 18)
# Range in test   (0 - 18)
#
# Feature num_var18_0
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_var20_0
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_var20
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_var24_0
# Range target=0  (0 - 9)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature num_var24
# Range target=0  (0 - 6)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature num_var26_0
# Range target=0  (0 - 33)
# Range target=1  (0 - 12)
# Range in test   (0 - 18)
#
# Feature num_var25_0
# Range target=0  (0 - 33)
# Range target=1  (0 - 12)
# Range in test   (0 - 18)
#
# Feature num_op_var40_hace2
# Range target=0  (0 - 117)
# Range target=1  (0 - 12)
# Range in test   (0 - 78)
#
# Feature num_op_var40_hace3
# Range target=0  (0 - 48)
# Range target=1  (0 - 0)
# Range in test   (0 - 15)
#
# Feature num_op_var40_ult1
# Range target=0  (0 - 234)
# Range target=1  (0 - 51)
# Range in test   (0 - 99)
#
# Feature num_op_var40_ult3
# Range target=0  (0 - 351)
# Range target=1  (0 - 51)
# Range in test   (0 - 144)
#
# Feature num_op_var41_hace2
# Range target=0  (0 - 249)
# Range target=1  (0 - 129)
# Range in test   (0 - 231)
#
# Feature num_op_var41_hace3
# Range target=0  (0 - 81)
# Range target=1  (0 - 30)
# Range in test   (0 - 144)
#
# Feature num_op_var41_ult1
# Range target=0  (0 - 468)
# Range target=1  (0 - 174)
# Range in test   (0 - 333)
#
# Feature num_op_var41_ult3
# Range target=0  (0 - 468)
# Range target=1  (0 - 204)
# Range in test   (0 - 489)
#
# Feature num_op_var39_hace2
# Range target=0  (0 - 249)
# Range target=1  (0 - 129)
# Range in test   (0 - 231)
#
# Feature num_op_var39_hace3
# Range target=0  (0 - 81)
# Range target=1  (0 - 30)
# Range in test   (0 - 144)
#
# Feature num_op_var39_ult1
# Range target=0  (0 - 468)
# Range target=1  (0 - 174)
# Range in test   (0 - 333)
#
# Feature num_op_var39_ult3
# Range target=0  (0 - 468)
# Range target=1  (0 - 204)
# Range in test   (0 - 522)
#
# Feature num_var30_0
# Range target=0  (0 - 33)
# Range target=1  (0 - 114)
# Range in test   (0 - 45)
#
# Feature num_var30
# Range target=0  (0 - 33)
# Range target=1  (0 - 9)
# Range in test   (0 - 24)
#
# Feature num_var31_0
# Range target=0  (0 - 36)
# Range target=1  (0 - 21)
# Range in test   (0 - 66)
#
# Feature num_var31
# Range target=0  (0 - 27)
# Range target=1  (0 - 18)
# Range in test   (0 - 18)
#
# Feature num_var32_0
# Range target=0  (0 - 12)
# Range target=1  (0 - 6)
# Range in test   (0 - 12)
#
# Feature num_var33_0
# Range target=0  (0 - 12)
# Range target=1  (0 - 0)
# Range in test   (0 - 6)
#
# Feature num_var33
# Range target=0  (0 - 6)
# Range target=1  (0 - 0)
# Range in test   (0 - 6)
#
# Feature num_var34_0
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_var35
# Range target=0  (0 - 36)
# Range target=1  (0 - 21)
# Range in test   (0 - 42)
#
# Feature num_var37_med_ult2
# Range target=0  (0 - 105)
# Range target=1  (0 - 39)
# Range in test   (0 - 117)
#
# Feature num_var37_0
# Range target=0  (0 - 114)
# Range target=1  (0 - 45)
# Range in test   (0 - 84)
#
# Feature num_var39_0
# Range target=0  (0 - 33)
# Range target=1  (0 - 12)
# Range in test   (0 - 39)
#
# Feature num_var40_0
# Range target=0  (0 - 3)
# Range target=1  (0 - 6)
# Range in test   (0 - 6)
#
# Feature num_var41_0
# Range target=0  (0 - 33)
# Range target=1  (0 - 12)
# Range in test   (0 - 39)
#
# Feature num_var42_0
# Range target=0  (0 - 18)
# Range target=1  (0 - 114)
# Range in test   (0 - 45)
#
# Feature num_var42
# Range target=0  (0 - 18)
# Range target=1  (0 - 9)
# Range in test   (0 - 15)
#
# Feature num_var44_0
# Range target=0  (0 - 6)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature num_var44
# Range target=0  (0 - 3)
# Range target=1  (0 - 3)
# Range in test   (0 - 6)
#
# Feature saldo_var1
# Range target=0  (-0.9 - 3000000.0)
# Range target=1  (0.0 - 4539.87)
# Range in test   (0.0 - 241299.27)
#
# Feature saldo_var5
# Range target=0  (-1496.64 - 619329.15)
# Range target=1  (-2895.72 - 137614.62)
# Range in test   (-1831.74 - 600000.0)
#
# Feature saldo_var6
# Range target=0  (0.0 - 19531.8)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 12627.0)
#
# Feature saldo_var8
# Range target=0  (-4942.26 - 240045.0)
# Range target=1  (-798.48 - 60098.49)
# Range in test   (-3972.24 - 375060.0)
#
# Feature saldo_var12
# Range target=0  (0.0 - 3008077.32)
# Range target=1  (0.0 - 506413.14)
# Range in test   (0.0 - 4202599.17)
#
# Feature saldo_var13_corto
# Range target=0  (0.0 - 450000.0)
# Range target=1  (0.0 - 309000.0)
# Range in test   (0.0 - 450000.0)
#
# Feature saldo_var13_largo
# Range target=0  (0.0 - 1500000.0)
# Range target=1  (0.0 - 150000.0)
# Range in test   (0.0 - 1008000.0)
#
# Feature saldo_var13_medio
# Range target=0  (0 - 30000)
# Range target=1  (0 - 0)
# Range in test   (0 - 36000)
#
# Feature saldo_var13
# Range target=0  (0.0 - 1500000.0)
# Range target=1  (0.0 - 309000.0)
# Range in test   (0.0 - 1008000.0)
#
# Feature saldo_var14
# Range target=0  (0.0 - 450000.0)
# Range target=1  (0.0 - 19053.78)
# Range in test   (0.0 - 373312.11)
#
# Feature saldo_var17
# Range target=0  (0.0 - 6119500.14)
# Range target=1  (0.0 - 288188.97)
# Range in test   (0.0 - 557236.17)
#
# Feature saldo_var18
# Range target=0  (0 - 3000000)
# Range target=1  (0 - 0)
# Range in test   (0 - 240000)
#
# Feature saldo_var20
# Range target=0  (0.0 - 455858.16)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 156316.44)
#
# Feature saldo_var24
# Range target=0  (0.0 - 3008077.32)
# Range target=1  (0.0 - 506413.14)
# Range in test   (0.0 - 4202599.17)
#
# Feature saldo_var26
# Range target=0  (0.0 - 69756.72)
# Range target=1  (0.0 - 10381.29)
# Range in test   (0.0 - 58264.68)
#
# Feature saldo_var25
# Range target=0  (0.0 - 69756.72)
# Range target=1  (0.0 - 10381.29)
# Range in test   (0.0 - 58264.68)
#
# Feature saldo_var30
# Range target=0  (-4942.26 - 3458077.32)
# Range target=1  (-2895.72 - 506443.14)
# Range in test   (-3972.24 - 4212656.07)
#
# Feature saldo_var31
# Range target=0  (0.0 - 6119500.14)
# Range target=1  (0.0 - 288188.97)
# Range in test   (0.0 - 557236.17)
#
# Feature saldo_var32
# Range target=0  (0.0 - 12210.78)
# Range target=1  (0.0 - 4115.22)
# Range in test   (0.0 - 13522.89)
#
# Feature saldo_var33
# Range target=0  (0.0 - 142078.8)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 162964.56)
#
# Feature saldo_var34
# Range target=0  (0 - 36000)
# Range target=1  (0 - 0)
# Range in test   (0 - 54000)
#
# Feature saldo_var37
# Range target=0  (0.0 - 60000.0)
# Range target=1  (0.0 - 21261.09)
# Range in test   (0.0 - 90000.0)
#
# Feature saldo_var40
# Range target=0  (-0.9 - 8192.61)
# Range target=1  (0.0 - 4539.87)
# Range in test   (0.0 - 9966.0)
#
# Feature saldo_var42
# Range target=0  (-4942.26 - 3008077.32)
# Range target=1  (-2895.72 - 506443.14)
# Range in test   (-3972.24 - 4212656.07)
#
# Feature saldo_var44
# Range target=0  (0.0 - 740006.61)
# Range target=1  (0.0 - 98415.0)
# Range in test   (0.0 - 498089.79)
#
# Feature var36
# Range target=0  (0 - 99)
# Range target=1  (1 - 99)
# Range in test   (0 - 99)
#
# Feature delta_imp_amort_var18_1y3
# Range target=0  (0 - 9999999999)
# Range target=1  (0 - 0)
# Range in test   (0 - 9999999999)
#
# Feature delta_imp_amort_var34_1y3
# Range target=0  (0 - 9999999999)
# Range target=1  (0 - 0)
# Range in test   (0 - 9999999999)
#
# Feature delta_imp_aport_var17_1y3
# Range target=0  (-1.0 - 9999999999.0)
# Range target=1  (0.0 - 9999999999.0)
# Range in test   (-1.0 - 9999999999.0)
#
# Feature delta_imp_aport_var33_1y3
# Range target=0  (-1.0 - 9999999999.0)
# Range target=1  (0.0 - 0.0)
# Range in test   (-1.0 - 9999999999.0)
#
# Feature delta_imp_compra_var44_1y3
# Range target=0  (-1.0 - 9999999999.0)
# Range target=1  (0.0 - 9999999999.0)
# Range in test   (-1.0 - 9999999999.0)
#
# Feature delta_imp_reemb_var17_1y3
# Range target=0  (-1 - 9999999999)
# Range target=1  (0 - 9999999999)
# Range in test   (0 - 9999999999)
#
# Feature delta_imp_reemb_var33_1y3
# Range target=0  (0 - 9999999999)
# Range target=1  (0 - 0)
# Range in test   (0 - 0)
#
# Feature delta_imp_trasp_var17_in_1y3
# Range target=0  (-1 - 9999999999)
# Range target=1  (0 - 0)
# Range in test   (-1 - 9999999999)
#
# Feature delta_imp_trasp_var17_out_1y3
# Range target=0  (0 - 9999999999)
# Range target=1  (0 - 0)
# Range in test   (0 - 0)
#
# Feature delta_imp_trasp_var33_in_1y3
# Range target=0  (-1 - 9999999999)
# Range target=1  (0 - 0)
# Range in test   (-1 - 9999999999)
#
# Feature delta_imp_trasp_var33_out_1y3
# Range target=0  (0 - 9999999999)
# Range target=1  (0 - 0)
# Range in test   (0 - 9999999999)
#
# Feature delta_imp_venta_var44_1y3
# Range target=0  (-1.0 - 9999999999.0)
# Range target=1  (0.0 - 0.0)
# Range in test   (-1.0 - 9999999999.0)
#
# Feature delta_num_aport_var17_1y3
# Range target=0  (-1.0 - 9999999999.0)
# Range target=1  (0.0 - 9999999999.0)
# Range in test   (-1.0 - 9999999999.0)
#
# Feature delta_num_aport_var33_1y3
# Range target=0  (-1.0 - 9999999999.0)
# Range target=1  (0.0 - 0.0)
# Range in test   (-1.0 - 9999999999.0)
#
# Feature delta_num_compra_var44_1y3
# Range target=0  (-1.0 - 9999999999.0)
# Range target=1  (0.0 - 9999999999.0)
# Range in test   (-1.0 - 9999999999.0)
#
# Feature delta_num_venta_var44_1y3
# Range target=0  (-1.0 - 9999999999.0)
# Range target=1  (0.0 - 0.0)
# Range in test   (-1.0 - 9999999999.0)
#
# Feature imp_amort_var18_ult1
# Range target=0  (0.0 - 15691.8)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 2672.43)
#
# Feature imp_amort_var34_ult1
# Range target=0  (0.0 - 1096.02)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 994.47)
#
# Feature imp_aport_var13_hace3
# Range target=0  (0.0 - 840000.0)
# Range target=1  (0.0 - 210000.0)
# Range in test   (0.0 - 1008000.0)
#
# Feature imp_aport_var13_ult1
# Range target=0  (0.0 - 450000.0)
# Range target=1  (0.0 - 105000.0)
# Range in test   (0.0 - 450000.0)
#
# Feature imp_aport_var17_hace3
# Range target=0  (0.0 - 6083691.87)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 555824.4)
#
# Feature imp_aport_var17_ult1
# Range target=0  (0.0 - 432457.32)
# Range target=1  (0.0 - 134507.67)
# Range in test   (0.0 - 339075.0)
#
# Feature imp_aport_var33_hace3
# Range target=0  (0 - 36000)
# Range target=1  (0 - 0)
# Range in test   (0.0 - 36497.67)
#
# Feature imp_aport_var33_ult1
# Range target=0  (0 - 1260)
# Range target=1  (0 - 0)
# Range in test   (0.0 - 24000.0)
#
# Feature imp_var7_emit_ult1
# Range target=0  (0.0 - 145384.92)
# Range target=1  (0.0 - 0.0)
# Range in test   (0 - 526500)
#
# Feature imp_var7_recib_ult1
# Range target=0  (0.0 - 1039260.0)
# Range target=1  (0.0 - 84000.0)
# Range in test   (0.0 - 850460.19)
#
# Feature imp_compra_var44_hace3
# Range target=0  (0.0 - 210001.35)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 596253.0)
#
# Feature imp_compra_var44_ult1
# Range target=0  (0.0 - 3410058.66)
# Range target=1  (0.0 - 95640.0)
# Range in test   (0.0 - 458175.42)
#
# Feature imp_reemb_var13_ult1
# Range target=0  (0.0 - 450000.0)
# Range target=1  (0.0 - 210000.0)
# Range in test   (0 - 366060)
#
# Feature imp_reemb_var17_hace3
# Range target=0  (0.0 - 12027.15)
# Range target=1  (0.0 - 0.0)
# Range in test   (0 - 0)
#
# Feature imp_reemb_var17_ult1
# Range target=0  (0.0 - 133926.27)
# Range target=1  (0.0 - 182132.97)
# Range in test   (0.0 - 211775.58)
#
# Feature imp_reemb_var33_ult1
# Range target=0  (0 - 1200)
# Range target=1  (0 - 0)
# Range in test   (0 - 0)
#
# Feature imp_var43_emit_ult1
# Range target=0  (0.0 - 1155003.0)
# Range target=1  (0.0 - 540000.0)
# Range in test   (0.0 - 2880000.0)
#
# Feature imp_trans_var37_ult1
# Range target=0  (0.0 - 2310003.0)
# Range target=1  (0.0 - 483003.0)
# Range in test   (0.0 - 3000000.0)
#
# Feature imp_trasp_var17_in_hace3
# Range target=0  (0.0 - 96781.44)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 555824.4)
#
# Feature imp_trasp_var17_in_ult1
# Range target=0  (0.0 - 133730.58)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 199665.84)
#
# Feature imp_trasp_var17_out_ult1
# Range target=0  (0.0 - 69622.29)
# Range target=1  (0.0 - 0.0)
# Range in test   (0 - 0)
#
# Feature imp_trasp_var33_in_hace3
# Range target=0  (0.0 - 49581.27)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 149252.1)
#
# Feature imp_trasp_var33_in_ult1
# Range target=0  (0.0 - 13207.32)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 35310.6)
#
# Feature imp_trasp_var33_out_ult1
# Range target=0  (0 - 3000)
# Range target=1  (0 - 0)
# Range in test   (0.0 - 5625.33)
#
# Feature imp_venta_var44_hace3
# Range target=0  (0.0 - 209834.4)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 438202.5)
#
# Feature imp_venta_var44_ult1
# Range target=0  (0.0 - 2754476.46)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 463917.0)
#
# Feature ind_var7_emit_ult1
# Range target=0  (0 - 1)
# Range target=1  (0 - 0)
# Range in test   (0 - 1)
#
# Feature var21
# Range target=0  (0 - 30000)
# Range target=1  (0 - 7200)
# Range in test   (0 - 18000)
#
# Feature num_aport_var13_hace3
# Range target=0  (0 - 24)
# Range target=1  (0 - 3)
# Range in test   (0 - 18)
#
# Feature num_aport_var13_ult1
# Range target=0  (0 - 30)
# Range target=1  (0 - 3)
# Range in test   (0 - 12)
#
# Feature num_aport_var17_hace3
# Range target=0  (0 - 12)
# Range target=1  (0 - 0)
# Range in test   (0 - 39)
#
# Feature num_aport_var17_ult1
# Range target=0  (0 - 18)
# Range target=1  (0 - 21)
# Range in test   (0 - 27)
#
# Feature num_aport_var33_hace3
# Range target=0  (0 - 12)
# Range target=1  (0 - 0)
# Range in test   (0 - 9)
#
# Feature num_aport_var33_ult1
# Range target=0  (0 - 6)
# Range target=1  (0 - 0)
# Range in test   (0 - 12)
#
# Feature num_var7_emit_ult1
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 9)
#
# Feature num_var7_recib_ult1
# Range target=0  (0 - 24)
# Range target=1  (0 - 6)
# Range in test   (0 - 12)
#
# Feature num_compra_var44_hace3
# Range target=0  (0 - 9)
# Range target=1  (0 - 0)
# Range in test   (0 - 45)
#
# Feature num_compra_var44_ult1
# Range target=0  (0 - 39)
# Range target=1  (0 - 3)
# Range in test   (0 - 51)
#
# Feature num_ent_var16_ult1
# Range target=0  (0 - 60)
# Range target=1  (0 - 30)
# Range in test   (0 - 84)
#
# Feature num_var22_hace2
# Range target=0  (0 - 123)
# Range target=1  (0 - 63)
# Range in test   (0 - 78)
#
# Feature num_var22_hace3
# Range target=0  (0 - 108)
# Range target=1  (0 - 48)
# Range in test   (0 - 75)
#
# Feature num_var22_ult1
# Range target=0  (0 - 96)
# Range target=1  (0 - 42)
# Range in test   (0 - 51)
#
# Feature num_var22_ult3
# Range target=0  (0 - 234)
# Range target=1  (0 - 93)
# Range in test   (0 - 129)
#
# Feature num_med_var22_ult3
# Range target=0  (0 - 78)
# Range target=1  (0 - 30)
# Range in test   (0 - 42)
#
# Feature num_med_var45_ult3
# Range target=0  (0 - 267)
# Range target=1  (0 - 213)
# Range in test   (0 - 273)
#
# Feature num_meses_var13_largo_ult3
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_meses_var13_medio_ult3
# Range target=0  (0 - 2)
# Range target=1  (0 - 0)
# Range in test   (0 - 2)
#
# Feature num_meses_var17_ult3
# Range target=0  (0 - 3)
# Range target=1  (0 - 1)
# Range in test   (0 - 3)
#
# Feature num_meses_var29_ult3
# Range target=0  (0 - 2)
# Range target=1  (0 - 0)
# Range in test   (0 - 2)
#
# Feature num_meses_var33_ult3
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_meses_var44_ult3
# Range target=0  (0 - 3)
# Range target=1  (0 - 1)
# Range in test   (0 - 3)
#
# Feature num_op_var39_comer_ult1
# Range target=0  (0 - 438)
# Range target=1  (0 - 129)
# Range in test   (0 - 321)
#
# Feature num_op_var39_comer_ult3
# Range target=0  (0 - 600)
# Range target=1  (0 - 204)
# Range in test   (0 - 450)
#
# Feature num_op_var40_comer_ult1
# Range target=0  (0 - 210)
# Range target=1  (0 - 30)
# Range in test   (0 - 120)
#
# Feature num_op_var40_comer_ult3
# Range target=0  (0 - 582)
# Range target=1  (0 - 48)
# Range in test   (0 - 249)
#
# Feature num_op_var40_efect_ult1
# Range target=0  (0 - 24)
# Range target=1  (0 - 9)
# Range in test   (0 - 33)
#
# Feature num_op_var40_efect_ult3
# Range target=0  (0 - 24)
# Range target=1  (0 - 15)
# Range in test   (0 - 33)
#
# Feature num_op_var41_comer_ult1
# Range target=0  (0 - 438)
# Range target=1  (0 - 129)
# Range in test   (0 - 321)
#
# Feature num_op_var41_comer_ult3
# Range target=0  (0 - 438)
# Range target=1  (0 - 204)
# Range in test   (0 - 429)
#
# Feature num_op_var41_efect_ult1
# Range target=0  (0 - 90)
# Range target=1  (0 - 57)
# Range in test   (0 - 75)
#
# Feature num_op_var41_efect_ult3
# Range target=0  (0 - 156)
# Range target=1  (0 - 114)
# Range in test   (0 - 156)
#
# Feature num_op_var39_efect_ult1
# Range target=0  (0 - 90)
# Range target=1  (0 - 57)
# Range in test   (0 - 75)
#
# Feature num_op_var39_efect_ult3
# Range target=0  (0 - 156)
# Range target=1  (0 - 114)
# Range in test   (0 - 156)
#
# Feature num_reemb_var17_hace3
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 0)
#
# Feature num_reemb_var17_ult1
# Range target=0  (0 - 9)
# Range target=1  (0 - 21)
# Range in test   (0 - 12)
#
# Feature num_reemb_var33_ult1
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 0)
#
# Feature num_sal_var16_ult1
# Range target=0  (0 - 15)
# Range target=1  (0 - 6)
# Range in test   (0 - 9)
#
# Feature num_var43_emit_ult1
# Range target=0  (0 - 180)
# Range target=1  (0 - 66)
# Range in test   (0 - 60)
#
# Feature num_var43_recib_ult1
# Range target=0  (0 - 264)
# Range target=1  (0 - 30)
# Range in test   (0 - 282)
#
# Feature num_trasp_var11_ult1
# Range target=0  (0 - 93)
# Range target=1  (0 - 18)
# Range in test   (0 - 57)
#
# Feature num_trasp_var17_in_hace3
# Range target=0  (0 - 6)
# Range target=1  (0 - 0)
# Range in test   (0 - 6)
#
# Feature num_trasp_var17_in_ult1
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 6)
#
# Feature num_trasp_var17_out_ult1
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 0)
#
# Feature num_trasp_var33_in_hace3
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_trasp_var33_in_ult1
# Range target=0  (0 - 6)
# Range target=1  (0 - 0)
# Range in test   (0 - 6)
#
# Feature num_trasp_var33_out_ult1
# Range target=0  (0 - 3)
# Range target=1  (0 - 0)
# Range in test   (0 - 3)
#
# Feature num_venta_var44_hace3
# Range target=0  (0 - 6)
# Range target=1  (0 - 0)
# Range in test   (0 - 24)
#
# Feature num_venta_var44_ult1
# Range target=0  (0 - 39)
# Range target=1  (0 - 0)
# Range in test   (0 - 45)
#
# Feature num_var45_hace2
# Range target=0  (0 - 294)
# Range target=1  (0 - 342)
# Range in test   (0 - 426)
#
# Feature num_var45_hace3
# Range target=0  (0 - 339)
# Range target=1  (0 - 330)
# Range in test   (0 - 201)
#
# Feature num_var45_ult1
# Range target=0  (0 - 510)
# Range target=1  (0 - 306)
# Range in test   (0 - 402)
#
# Feature num_var45_ult3
# Range target=0  (0 - 801)
# Range target=1  (0 - 642)
# Range in test   (0 - 825)
#
# Feature saldo_medio_var5_hace2
# Range target=0  (-128.37 - 812137.26)
# Range target=1  (-47.13 - 165500.01)
# Range in test   (-1573.23 - 678060.0)
#
# Feature saldo_medio_var5_hace3
# Range target=0  (-6.09 - 1542339.36)
# Range target=1  (-8.04 - 164999.97)
# Range in test   (-32.85 - 405001.5)
#
# Feature saldo_medio_var5_ult1
# Range target=0  (-922.38 - 601428.6)
# Range target=1  (-733.05 - 84000.0)
# Range in test   (-1605.15 - 656187.09)
#
# Feature saldo_medio_var5_ult3
# Range target=0  (-476.07 - 544365.57)
# Range target=1  (-173.64 - 108250.02)
# Range in test   (-1036.08 - 482422.35)
#
# Feature saldo_medio_var8_hace2
# Range target=0  (-287.67 - 231351.99)
# Range target=1  (-151.95 - 6570.36)
# Range in test   (-118.02 - 264702.87)
#
# Feature saldo_medio_var8_hace3
# Range target=0  (0.0 - 77586.21)
# Range target=1  (0.0 - 1414.35)
# Range in test   (0.0 - 95260.56)
#
# Feature saldo_medio_var8_ult1
# Range target=0  (-3401.34 - 228031.8)
# Range target=1  (-705.96 - 56888.67)
# Range in test   (-3925.92 - 375060.0)
#
# Feature saldo_medio_var8_ult3
# Range target=0  (-1844.52 - 177582.0)
# Range target=1  (-292.47 - 56888.67)
# Range in test   (-869.31 - 216012.03)
#
# Feature saldo_medio_var12_hace2
# Range target=0  (0.0 - 3000538.14)
# Range target=1  (0.0 - 663568.56)
# Range in test   (0.0 - 4500000.0)
#
# Feature saldo_medio_var12_hace3
# Range target=0  (0.0 - 668335.32)
# Range target=1  (0.0 - 95815.95)
# Range in test   (0.0 - 1202339.22)
#
# Feature saldo_medio_var12_ult1
# Range target=0  (0.0 - 3004185.6)
# Range target=1  (0.0 - 599140.56)
# Range in test   (0.0 - 4356643.41)
#
# Feature saldo_medio_var12_ult3
# Range target=0  (0.0 - 2272859.43)
# Range target=1  (0.0 - 438282.45)
# Range in test   (0.0 - 3002214.48)
#
# Feature saldo_medio_var13_corto_hace2
# Range target=0  (0.0 - 450000.0)
# Range target=1  (0.0 - 287064.39)
# Range in test   (0.0 - 450000.0)
#
# Feature saldo_medio_var13_corto_hace3
# Range target=0  (0.0 - 304838.7)
# Range target=1  (0.0 - 155806.44)
# Range in test   (0.0 - 283333.32)
#
# Feature saldo_medio_var13_corto_ult1
# Range target=0  (0.0 - 450000.0)
# Range target=1  (0.0 - 309000.0)
# Range in test   (0.0 - 450000.0)
#
# Feature saldo_medio_var13_corto_ult3
# Range target=0  (0.0 - 450000.0)
# Range target=1  (0.0 - 287064.39)
# Range in test   (0.0 - 450000.0)
#
# Feature saldo_medio_var13_largo_hace2
# Range target=0  (0.0 - 840000.0)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 1008000.0)
#
# Feature saldo_medio_var13_largo_hace3
# Range target=0  (0.0 - 534000.0)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 420000.03)
#
# Feature saldo_medio_var13_largo_ult1
# Range target=0  (0.0 - 1500000.0)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 1008000.0)
#
# Feature saldo_medio_var13_largo_ult3
# Range target=0  (0.0 - 1034482.74)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 740000.01)
#
# Feature saldo_medio_var13_medio_hace2
# Range target=0  (0.0 - 7741.95)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 8129.04)
#
# Feature saldo_medio_var13_medio_ult3
# Range target=0  (0.0 - 18870.99)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 18600.0)
#
# Feature saldo_medio_var17_hace2
# Range target=0  (-0.03 - 4210084.23)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 556062.21)
#
# Feature saldo_medio_var17_hace3
# Range target=0  (0.0 - 2368558.95)
# Range target=1  (0.0 - 0.0)
# Range in test   (-0.06 - 248772.75)
#
# Feature saldo_medio_var17_ult1
# Range target=0  (0.0 - 3998687.46)
# Range target=1  (0.0 - 262209.99)
# Range in test   (0.0 - 556872.24)
#
# Feature saldo_medio_var17_ult3
# Range target=0  (0.0 - 3525776.88)
# Range target=1  (0.0 - 262209.99)
# Range in test   (0.0 - 453902.4)
#
# Feature saldo_medio_var29_hace2
# Range target=0  (0.0 - 10430.01)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 6899.97)
#
# Feature saldo_medio_var29_hace3
# Range target=0  (0.0 - 145.2)
# Range target=1  (0.0 - 0.0)
# Range in test   (0 - 0)
#
# Feature saldo_medio_var29_ult1
# Range target=0  (0.0 - 13793.67)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 9160.32)
#
# Feature saldo_medio_var29_ult3
# Range target=0  (0.0 - 7331.34)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 8030.16)
#
# Feature saldo_medio_var33_hace2
# Range target=0  (0.0 - 50003.88)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 146605.32)
#
# Feature saldo_medio_var33_hace3
# Range target=0  (0.0 - 20385.72)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 40080.6)
#
# Feature saldo_medio_var33_ult1
# Range target=0  (0.0 - 138831.63)
# Range target=1  (0.0 - 0.0)
# Range in test   (-0.6 - 162355.8)
#
# Feature saldo_medio_var33_ult3
# Range target=0  (0.0 - 91778.73)
# Range target=1  (0.0 - 0.0)
# Range in test   (-0.6 - 138054.96)
#
# Feature saldo_medio_var44_hace2
# Range target=0  (0.0 - 438329.22)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 453893.4)
#
# Feature saldo_medio_var44_hace3
# Range target=0  (0.0 - 24650.01)
# Range target=1  (0.0 - 0.0)
# Range in test   (0.0 - 217762.23)
#
# Feature saldo_medio_var44_ult1
# Range target=0  (0.0 - 681462.9)
# Range target=1  (0.0 - 34462.74)
# Range in test   (0.0 - 496198.08)
#
# Feature saldo_medio_var44_ult3
# Range target=0  (0.0 - 397884.3)
# Range target=1  (0.0 - 34462.74)
# Range in test   (0.0 - 354260.73)
#
# Feature var38
# Range target=0  (5163.75 - 22034738.76)
# Range target=1  (11136.63 - 3988595.1)
# Range in test   (1202.73 - 28894395.51)
#
# Feature TARGET
# Range target=0  (0 - 0)
# Range target=1  (1 - 1)
# Range in test   (N/A - N/A)
